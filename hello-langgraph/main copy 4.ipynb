# %%
from langgraph.graph import StateGraph, START, END
from typing_extensions import TypedDict, Annotated
from langgraph.types import Send
import operator

# %%
from typing import Union

class State(TypedDict):
    words:list[str]
    output:Annotated[list[dict[str, Union[str,int]]], operator.add]

graph_builder = StateGraph(State)

# %%
def node_one(state:State):
    print(f"I want to count {len(state["words"])} words in my state.")
    return { }

def node_two(word:str):
    return {
        "output":[
            {
                "word":word,
                "letters":len(word),
            }
        ]
    }

# %%
graph_builder.add_node("node_one", node_one)
graph_builder.add_node("node_two", node_two)

def dispartcher(state:State):
    return [Send("node_two", word) for word in state["words"]]

# 연결
graph_builder.add_edge(START,"node_one")
graph_builder.add_conditional_edges("node_one", dispartcher, ["node_two"])
graph_builder.add_edge("node_two", END)

# %%
# 그래프 컴파일
# 그래프랑 edge들이 다~말이되는지화긘 (유효성검사)
graph = graph_builder.compile()
graph.invoke({
   "words": ["hello", "world","how","are","you","doing"]
})
# Out:
# I want to count 6 words in my state.
# node_two ->  hello
# node_two ->  world
# node_two ->  how
# node_two ->  are
# node_two ->  doing
# node_two ->  you
# {'words': ['hello', 'world', 'how', 'are', 'you', 'doing']}
