# %%
from langgraph.graph import END, START, StateGraph
from langgraph.types import Send, interrupt, Command
from typing import TypedDict
import subprocess
from openai import OpenAI
import textwrap
from langchain.chat_models import init_chat_model
from typing_extensions import Annotated
import operator
import base64
from langgraph.checkpoint.memory import InMemorySaver

memory = InMemorySaver()

llm = init_chat_model("openai:gpt-4o-mini")


class State(TypedDict):

    video_file: str
    audio_file: str
    transcription: str
    summaries: Annotated[list[str], operator.add]
    thumbnail_prompts: Annotated[list[str], operator.add]
    thumbnail_sketches: Annotated[list[str], operator.add]
    final_summary: str
    user_feedback: str
    chosen_prompt: str

# %%
def extract_audio(state: State):
    output_file = state["video_file"].replace("mp4", "mp3")
    command = [
        "ffmpeg", # 실행모듈
        "-i", # 임풋
        state["video_file"],
        "-filter:a",
        "atempo=2.0",
        "-y",
        output_file,
    ]
    subprocess.run(command)
    return {
        "audio_file": output_file,
    }


def transcribe_audio(state: State):
    client = OpenAI()
    with open(state["audio_file"], "rb") as audio_file:
        transcription = client.audio.transcriptions.create(
            model="whisper-1",
            response_format="text",
            file=audio_file,
            language="ko",
            prompt="먼작귀, 애니메이션",
        )
        return {
            "transcription": transcription,
        }


def dispatch_summarizers(state: State):
    transcription = state["transcription"]
    chunks = []
    for i, chunk in enumerate(textwrap.wrap(transcription, 500)):
        chunks.append({"id": i + 1, "chunk": chunk})
    return [Send("summarize_chunk", chunk) for chunk in chunks]


def summarize_chunk(chunk):
    chunk_id = chunk["id"]
    chunk = chunk["chunk"]

    response = llm.invoke(
        f"""
        Please summarize the following text.

        Text: {chunk}
        """
    )
    summary = f"[Chunk {chunk_id}] {response.content}"
    return {
        "summaries": [summary],
    }


def mega_summary(state: State):

    all_summaries = "\n".join(state["summaries"])

    prompt = f"""
        You are given multiple summaries of different chunks from a video transcription.

        Please create a comprehensive final summary that combines all the key points.

        Individual summaries:

        {all_summaries}
    """

    response = llm.invoke(prompt)

    return {
        "final_summary": response.content,
    }


def dispatch_artists(state: State):
    return [
        Send(
            "generate_thumbnails",
            {
                "id": i,
                "summary": state["final_summary"],
            },
        )
        for i in [1, 2, 3, 4, 5]
    ]


def generate_thumbnails(args):
    concept_id = args["id"]
    summary = args["summary"]

    prompt = f"""
    Based on this video summary, create a detailed visual prompt for a YouTube thumbnail.

    Create a detailed prompt for generating a thumbnail image that would attract viewers. Include:
        - Main visual elements
        - Color scheme
        - Text overlay suggestions
        - Overall composition
    
    Summary: {summary}
    """

    response = llm.invoke(prompt)

    thumbnail_prompt = response.content

    client = OpenAI()

    result = client.images.generate(
        model="gpt-image-1",
        prompt=thumbnail_prompt,
        quality="low",
        moderation="low",
        size="auto",
    )

    image_bytes = base64.b64decode(result.data[0].b64_json)

    filename = f"thumbnail_{concept_id}.jpg"

    with open(filename, "wb") as file:
        file.write(image_bytes)

    return {
        "thumbnail_prompts": [thumbnail_prompt],
        "thumbnail_sketches": [filename],
    }


def human_feedback(state: State):
    answer = interrupt(
        {
            "chosen_thumbnail": "Which thumbnail do you like the most?",
            "feedback": "Provide any feedback or changes you'd like for the final thumbnail.",
        }
    )
    user_feedback = answer["user_feedback"]
    chosen_prompt = answer["chosen_prompt"]
    return {
        "user_feedback": user_feedback,
        "chosen_prompt": state["thumbnail_prompts"][chosen_prompt - 1],
    }


def generate_hd_thumbnail(state: State):

    chosen_prompt = state["chosen_prompt"]
    user_feedback = state["user_feedback"]

    prompt = f"""
    You are a professional YouTube thumbnail designer. Take this original thumbnail prompt and create an enhanced version that incorporates the user's specific feedback.

    ORIGINAL PROMPT:
    {chosen_prompt}

    USER FEEDBACK TO INCORPORATE:
    {user_feedback}

    Create an enhanced prompt that:
        1. Maintains the core concept from the original prompt
        2. Specifically addresses and implements the user's feedback requests
        3. Adds professional YouTube thumbnail specifications:
            - High contrast and bold visual elements
            - Clear focal points that draw the eye
            - Professional lighting and composition
            - Optimal text placement and readability with generous padding from edges
            - Colors that pop and grab attention
            - Elements that work well at small thumbnail sizes
            - IMPORTANT: Always ensure adequate white space/padding between any text and the image borders
    """

    response = llm.invoke(prompt)

    final_thumbnail_prompt = response.content

    client = OpenAI()

    result = client.images.generate(
        model="gpt-image-1",
        prompt=final_thumbnail_prompt,
        quality="high",
        moderation="low",
        size="auto",
    )

    image_bytes = base64.b64decode(result.data[0].b64_json)

    with open("thumbnail_final.jpg", "wb") as file:
        file.write(image_bytes)

# %%
graph_builder = StateGraph(State)

graph_builder.add_node("extract_audio", extract_audio)
graph_builder.add_node("transcribe_audio", transcribe_audio)
graph_builder.add_node("summarize_chunk", summarize_chunk)
graph_builder.add_node("mega_summary", mega_summary)
graph_builder.add_node("generate_thumbnails", generate_thumbnails)
graph_builder.add_node("human_feedback", human_feedback)
graph_builder.add_node("generate_hd_thumbnail", generate_hd_thumbnail)

graph_builder.add_edge(START, "extract_audio")
graph_builder.add_edge("extract_audio", "transcribe_audio")
graph_builder.add_conditional_edges(
    "transcribe_audio", dispatch_summarizers, ["summarize_chunk"]
)
graph_builder.add_edge("summarize_chunk", "mega_summary")
graph_builder.add_conditional_edges(
    "mega_summary", dispatch_artists, ["generate_thumbnails"]
)
graph_builder.add_edge("generate_thumbnails", "human_feedback")
graph_builder.add_edge("human_feedback", "generate_hd_thumbnail")
graph_builder.add_edge("generate_hd_thumbnail", END)

graph = graph_builder.compile(checkpointer=memory)

# %%
config = {
    "configurable": {
        "thread_id": "1",
    },
}

# %%
graph.invoke(
    {"video_file": "chii.mp4"},
    config=config,
)
# Out:
# {'video_file': 'chii.mp4',
#  'audio_file': 'chii.mp3',
#  'transcription': '뭐야 벌써 아침이네 혼자 말을 해 구워진 빵에 버터 발라발라 땀이 두배 잔뜩 머금어서 아직 촉촉해\n',
#  'summaries': ['[Chunk 1] The text expresses surprise at the arrival of morning and describes a scene where someone is talking to themselves while spreading butter on a piece of toasted bread, which is still moist with sweat.'],
#  'thumbnail_prompts': ["**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Character:** A mid-30s individual with an expressive face, looking thoughtfully at a slice of toast. They should be depicted in a cozy kitchen setting, with soft morning light streaming in through the window.\n2. **Toast and Butter:** A close-up of the individual's hand spreading creamy butter on a golden-brown slice of toast, capturing the luscious texture of the butter melting slightly.\n3. **Background Details:** A small kitchen table with an array of colorful ingredients (like jam in a jar, fresh fruit, a coffee cup) to create a welcoming atmosphere. A few kitchen appliances could be visible, like a kettle or toaster, subtly blurred to maintain focus on the main character.\n4. **Emotion:** The character’s expression should convey a sense of wonder or contemplation, hinting at the theme of self-conversation and introspection.\n\n**Color Scheme:**\n- **Warm and Inviting Tones:** Use soft yellows and warm beige inspired by morning light, contrasted with pops of green (from the fresh ingredients) and a hint of deep brown (for the toast).\n- **Soft Focus on Background:** Slightly blurred greens and browns for the kitchen background to create depth.\n\n**Text Overlay Suggestions:**\n- **Main Title:** “Morning Conversations” in a bold, playful font. \n- **Subtitle:** “A Simple Breakfast Ritual” in a smaller, elegant font below it. \n- **Color and Style:** Use white or light yellow for the text, ensuring it pops against the background but retains readability. Consider adding a subtle drop shadow to enhance visibility.\n\n**Overall Composition:**\n- Center the character slightly off to the left, with the toast and butter in sharp focus on the right side of the thumbnail. \n- Ensure the text is positioned in the upper part of the thumbnail, leaving enough space around it for a clean look.\n- Use a soft vignette effect around the edges to draw the viewer’s eye towards the center, creating a cozy and inviting feel that invites viewers to click on the video.\n\nThis prompt is designed to create an engaging thumbnail that reflects both the intimate nature of the video while also hinting at the simplicity and depth found in everyday moments.",
#   "**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n- **Central Character:** A cheerful, middle-aged individual (with a warm smile) engaged in the act of spreading butter on a slice of golden-brown, toasted bread. The person's body should be slightly turned, showcasing the action clearly.\n- **Kitchen Background:** A bright, inviting kitchen setting with soft natural light streaming through a window, illuminating the scene. Include elements like a coffee mug, a small potted plant, and utensils to create a cozy atmosphere.\n- **Bread Close-Up:** A zoomed-in visual of the toast showing the gooey butter melting into the bread, emphasizing the texture and warmth.\n- **Self-Conversation Element:** A thought bubble or a subtle reflection of the person's thoughts (like animated icons of hearts or food) to indicate their inner dialogue, adding a whimsical touch.\n\n**Color Scheme:**\n- **Warm Tones:** Use soft, warm colors like buttery yellows, gentle browns, and a hint of light teal or mint for an inviting feel. The toast should be a rich golden brown, while the background should remain light and airy.\n- **Contrast:** Ensure that the person’s clothing (perhaps a light blue or pastel apron) contrasts nicely against the kitchen backdrop to draw attention to them.\n\n**Text Overlay Suggestions:**\n- **Main Text:** Bold, playful font reading: “Morning Conversations!” (or an engaging title relevant to the video theme).\n- **Subtitle/Text Addition:** Below the main title, in a smaller font: “Transforming Breakfast into a Joyful Ritual”. Use a contrasting color for this text to ensure it pops against the background, perhaps white or light yellow.\n\n**Overall Composition:**\n- The composition should be dynamic, with the character on one side of the thumbnail (slightly off-center) while the text is placed on the opposite side, creating a balanced layout that guides the viewer's eye.\n- Integrate visual elements like flourishes or small icons (like toast, butter pats, coffee cups) around the text to enhance visual appeal and create a cohesive look.\n- Ensure the overall thumbnail is bright and inviting, evoking comfort and curiosity to encourage viewers to click on the video.",
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Character**: Feature a smiling individual (gender-neutral) in a cozy kitchen environment. They should be standing in front of the counter, engaged in spreading butter on a slice of golden-brown toast. Ensure the butter appears glossy and melting for added texture.\n2. **Background**: The kitchen should look warm and inviting, with soft morning light streaming in through a window. Include countertop details like a small potted plant, a coffee mug, and utensils to create an authentic atmosphere.\n3. **Close-Up Action**: Incorporate a close-up shot of the toast being buttered in one corner, emphasizing the tactile, sensory appeal of the moment.\n\n**Color Scheme:**\n- Use warm and inviting colors such as soft yellows, light browns, and cream shades for a cozy breakfast vibe. Accents of green from the plant and a splash of rich brown from the coffee mug will add depth and warmth.\n- Consider a soft gradient that transitions from the light outside to a slightly deeper shade inside the kitchen, creating an inviting and uplifting ambiance.\n\n**Text Overlay Suggestions:**\n- Bold primary text: “A Morning Ritual!”\n  - Font Style: Use a friendly, handwritten or casual script font to convey warmth and approachability.\n  - Text Color: Bright white or light yellow with a subtle drop shadow for contrast against the darker background.\n- Secondary text (if space allows): “Spreading Joy, One Toast at a Time” in a smaller, simpler font beneath the primary text, in a complementary color.\n\n**Overall Composition:**\n- Position the central character slightly off-center to allow for visual breathing space, with the toast close to the edge of the thumbnail for a dynamic layout.\n- The text should curve around the character or be placed at the top and bottom of the thumbnail to guide the viewer’s eye naturally.\n- Make sure the elements are well-balanced, ensuring enough high-contrast areas for visibility of text while keeping it cohesive and appealing.\n- Include a subtle, stylized border or drop shadow around the entire thumbnail to make it stand out against other videos on YouTube.\n\nThis detailed prompt should create an engaging and eye-catching thumbnail that invites viewers to click and enjoy the video’s intimate and relatable moment.',
#   '**YouTube Thumbnail Visual Prompt:**\n\n**Main Visual Elements:**\n1. **Central Character:** A cheerful, relatable individual (gender-neutral) standing at a kitchen counter, engaged in a self-conversation. They are smiling slightly, with an animated facial expression to convey a mix of contemplation and joy.\n2. **Breakfast Scene:** The character is in the process of spreading soft butter on a warm, golden-brown slice of toast. Place the toast prominently in the foreground with a visible knife smeared with butter for added texture.\n3. **Kitchen Background:** A bright and inviting kitchen scene that shows hints of morning light pouring in through a window. To maintain focus on the character and toast, ensure the background is slightly blurred.\n4. **Additional Elements:** Include a steaming cup of coffee or tea on the counter beside the toast, along with a fruit bowl or cheerful kitchen plants in the background to add warmth and color.\n\n**Color Scheme:**\n- **Warm Tones:** Use soft yellows and warm browns to evoke a cozy morning feeling, capturing the warmth of freshly toasted bread and sunlit kitchen.\n- **Accent Colors:** Introduce accents of bright blue or green (for the coffee mug or fruits) to contrast the warm tones and make the image pop.\n- **Text Contrast:** Use white or light-colored text that stands out against the warm background, ensuring easy readability.\n\n**Text Overlay Suggestions:**\n1. Main Title: "Morning Moments!"\n   - Font: Bold and playful, giving an inviting vibe.\n   - Position: Placed at the top, slightly arched to fit the warmth of the scene.\n   \n2. Subtitle (small text): "Self-Conversations Over Toast" \n   - Font: A more understated, friendly font, possibly italicized.\n   - Position: Placed at the bottom or along the side, ensuring it doesn’t cover critical visual elements.\n\n**Overall Composition:**\n- Utilize the rule of thirds; place the character slightly off-center to draw the viewer’s eye naturally towards both them and the toast.\n- Ensure there’s enough space in the thumbnail for the text overlay while keeping the elements balanced and engaging.\n- The blend of inviting colors and cheerful expressions will evoke curiosity, enticing viewers to click and engage with the video\'s content about intimate morning routines and self-reflection.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Figure:** A cheerful, relatable person (can be male or female) in a cozy kitchen setting. They should be mid-action, spreading butter on a piece of warm toast, with a warm smile on their face to convey a sense of joy.\n2. **Toast Focus:** The toast should be prominently displayed, with glistening butter melting on its surface, inviting viewers to feel the warmth and taste the freshness.\n3. **Background Details:** A soft-focus kitchen scene in the background, featuring elements like a vintage toaster, a sunny window with soft light pouring through, and a coffee cup steaming nearby. This sets an inviting and homely atmosphere.\n4. **Speech Bubble:** Include a playful speech bubble above the individual, capturing a snippet of their self-conversation (e.g., "Another delicious day begins!").\n\n**Color Scheme:**\n- **Warm Tones:** Use a palette of warm yellows, soft browns, and creamy whites to evoke feelings of comfort and warmth. \n- **Accent Colors:** Incorporate hints of pastel colors (light blue or soft green) for kitchen elements to add balance without overwhelming the main focus.\n- **Contrast:** Ensure the toast and butter have a slightly brighter hue against the background to draw attention immediately.\n\n**Text Overlay Suggestions:**\n- **Main Title Text:** "Morning Bliss!" in bold, playful fonts at the top of the thumbnail. Use white or light yellow with a subtle shadow for better visibility.\n- **Subtext:** A smaller line below the main title saying "Join the Breakfast Chat!" in a contrasting font style, perhaps in a light pastel color, to make it eye-catching but not overpowering.\n\n**Overall Composition:**\n- The individual should be positioned slightly off-center (rule of thirds), with the toast angled towards the viewer to create depth.\n- The text overlay should be placed at the upper and lower parts of the thumbnail to keep the central focus on the toast and the person, avoiding clutter.\n- A subtle drop shadow behind the main title text can help it stand out against the background for enhanced readability.\n\nBy combining a joyful scene with warm colors and engaging text, this thumbnail will evoke curiosity and draw viewers in, enticing them to click and explore the daily ritual depicted in the video.'],
#  'thumbnail_sketches': ['thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg'],
#  'final_summary': 'The video transcription portrays a surprising morning scene where an individual engages in a self-conversation while preparing breakfast. The focus is on the person spreading butter on a piece of warm, freshly toasted bread, which adds a tactile and sensory element to the moment, emphasizing both the mundane and intimate aspects of the daily routine.',
#  '__interrupt__': [Interrupt(value={'chosen_thumbnail': 'Which thumbnail do you like the most?', 'feedback': "Provide any feedback or changes you'd like for the final thumbnail."}, id='4d8e0e91a9d4c2b1c60f3d7ca72f41fa')]}

# %%
response = {
    "user_feedback": "Make sure the fella is smiling, remove any mention of audible, or any logo, and give it a photo realistic, 3d style.",
    "chosen_prompt": 1,
}

graph.invoke(
    Command(resume=response),
    config=config,
)
# Out:
# {'video_file': 'chii.mp4',
#  'audio_file': 'chii.mp3',
#  'transcription': '뭐야 벌써 아침이네 혼자 말을 해 구워진 빵에 버터 발라발라 땀이 두배 잔뜩 머금어서 아직 촉촉해\n',
#  'summaries': ['[Chunk 1] The text expresses surprise at the arrival of morning and describes a scene where someone is talking to themselves while spreading butter on a piece of toasted bread, which is still moist with sweat.'],
#  'thumbnail_prompts': ["**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Character:** A mid-30s individual with an expressive face, looking thoughtfully at a slice of toast. They should be depicted in a cozy kitchen setting, with soft morning light streaming in through the window.\n2. **Toast and Butter:** A close-up of the individual's hand spreading creamy butter on a golden-brown slice of toast, capturing the luscious texture of the butter melting slightly.\n3. **Background Details:** A small kitchen table with an array of colorful ingredients (like jam in a jar, fresh fruit, a coffee cup) to create a welcoming atmosphere. A few kitchen appliances could be visible, like a kettle or toaster, subtly blurred to maintain focus on the main character.\n4. **Emotion:** The character’s expression should convey a sense of wonder or contemplation, hinting at the theme of self-conversation and introspection.\n\n**Color Scheme:**\n- **Warm and Inviting Tones:** Use soft yellows and warm beige inspired by morning light, contrasted with pops of green (from the fresh ingredients) and a hint of deep brown (for the toast).\n- **Soft Focus on Background:** Slightly blurred greens and browns for the kitchen background to create depth.\n\n**Text Overlay Suggestions:**\n- **Main Title:** “Morning Conversations” in a bold, playful font. \n- **Subtitle:** “A Simple Breakfast Ritual” in a smaller, elegant font below it. \n- **Color and Style:** Use white or light yellow for the text, ensuring it pops against the background but retains readability. Consider adding a subtle drop shadow to enhance visibility.\n\n**Overall Composition:**\n- Center the character slightly off to the left, with the toast and butter in sharp focus on the right side of the thumbnail. \n- Ensure the text is positioned in the upper part of the thumbnail, leaving enough space around it for a clean look.\n- Use a soft vignette effect around the edges to draw the viewer’s eye towards the center, creating a cozy and inviting feel that invites viewers to click on the video.\n\nThis prompt is designed to create an engaging thumbnail that reflects both the intimate nature of the video while also hinting at the simplicity and depth found in everyday moments.",
#   "**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n- **Central Character:** A cheerful, middle-aged individual (with a warm smile) engaged in the act of spreading butter on a slice of golden-brown, toasted bread. The person's body should be slightly turned, showcasing the action clearly.\n- **Kitchen Background:** A bright, inviting kitchen setting with soft natural light streaming through a window, illuminating the scene. Include elements like a coffee mug, a small potted plant, and utensils to create a cozy atmosphere.\n- **Bread Close-Up:** A zoomed-in visual of the toast showing the gooey butter melting into the bread, emphasizing the texture and warmth.\n- **Self-Conversation Element:** A thought bubble or a subtle reflection of the person's thoughts (like animated icons of hearts or food) to indicate their inner dialogue, adding a whimsical touch.\n\n**Color Scheme:**\n- **Warm Tones:** Use soft, warm colors like buttery yellows, gentle browns, and a hint of light teal or mint for an inviting feel. The toast should be a rich golden brown, while the background should remain light and airy.\n- **Contrast:** Ensure that the person’s clothing (perhaps a light blue or pastel apron) contrasts nicely against the kitchen backdrop to draw attention to them.\n\n**Text Overlay Suggestions:**\n- **Main Text:** Bold, playful font reading: “Morning Conversations!” (or an engaging title relevant to the video theme).\n- **Subtitle/Text Addition:** Below the main title, in a smaller font: “Transforming Breakfast into a Joyful Ritual”. Use a contrasting color for this text to ensure it pops against the background, perhaps white or light yellow.\n\n**Overall Composition:**\n- The composition should be dynamic, with the character on one side of the thumbnail (slightly off-center) while the text is placed on the opposite side, creating a balanced layout that guides the viewer's eye.\n- Integrate visual elements like flourishes or small icons (like toast, butter pats, coffee cups) around the text to enhance visual appeal and create a cohesive look.\n- Ensure the overall thumbnail is bright and inviting, evoking comfort and curiosity to encourage viewers to click on the video.",
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Character**: Feature a smiling individual (gender-neutral) in a cozy kitchen environment. They should be standing in front of the counter, engaged in spreading butter on a slice of golden-brown toast. Ensure the butter appears glossy and melting for added texture.\n2. **Background**: The kitchen should look warm and inviting, with soft morning light streaming in through a window. Include countertop details like a small potted plant, a coffee mug, and utensils to create an authentic atmosphere.\n3. **Close-Up Action**: Incorporate a close-up shot of the toast being buttered in one corner, emphasizing the tactile, sensory appeal of the moment.\n\n**Color Scheme:**\n- Use warm and inviting colors such as soft yellows, light browns, and cream shades for a cozy breakfast vibe. Accents of green from the plant and a splash of rich brown from the coffee mug will add depth and warmth.\n- Consider a soft gradient that transitions from the light outside to a slightly deeper shade inside the kitchen, creating an inviting and uplifting ambiance.\n\n**Text Overlay Suggestions:**\n- Bold primary text: “A Morning Ritual!”\n  - Font Style: Use a friendly, handwritten or casual script font to convey warmth and approachability.\n  - Text Color: Bright white or light yellow with a subtle drop shadow for contrast against the darker background.\n- Secondary text (if space allows): “Spreading Joy, One Toast at a Time” in a smaller, simpler font beneath the primary text, in a complementary color.\n\n**Overall Composition:**\n- Position the central character slightly off-center to allow for visual breathing space, with the toast close to the edge of the thumbnail for a dynamic layout.\n- The text should curve around the character or be placed at the top and bottom of the thumbnail to guide the viewer’s eye naturally.\n- Make sure the elements are well-balanced, ensuring enough high-contrast areas for visibility of text while keeping it cohesive and appealing.\n- Include a subtle, stylized border or drop shadow around the entire thumbnail to make it stand out against other videos on YouTube.\n\nThis detailed prompt should create an engaging and eye-catching thumbnail that invites viewers to click and enjoy the video’s intimate and relatable moment.',
#   '**YouTube Thumbnail Visual Prompt:**\n\n**Main Visual Elements:**\n1. **Central Character:** A cheerful, relatable individual (gender-neutral) standing at a kitchen counter, engaged in a self-conversation. They are smiling slightly, with an animated facial expression to convey a mix of contemplation and joy.\n2. **Breakfast Scene:** The character is in the process of spreading soft butter on a warm, golden-brown slice of toast. Place the toast prominently in the foreground with a visible knife smeared with butter for added texture.\n3. **Kitchen Background:** A bright and inviting kitchen scene that shows hints of morning light pouring in through a window. To maintain focus on the character and toast, ensure the background is slightly blurred.\n4. **Additional Elements:** Include a steaming cup of coffee or tea on the counter beside the toast, along with a fruit bowl or cheerful kitchen plants in the background to add warmth and color.\n\n**Color Scheme:**\n- **Warm Tones:** Use soft yellows and warm browns to evoke a cozy morning feeling, capturing the warmth of freshly toasted bread and sunlit kitchen.\n- **Accent Colors:** Introduce accents of bright blue or green (for the coffee mug or fruits) to contrast the warm tones and make the image pop.\n- **Text Contrast:** Use white or light-colored text that stands out against the warm background, ensuring easy readability.\n\n**Text Overlay Suggestions:**\n1. Main Title: "Morning Moments!"\n   - Font: Bold and playful, giving an inviting vibe.\n   - Position: Placed at the top, slightly arched to fit the warmth of the scene.\n   \n2. Subtitle (small text): "Self-Conversations Over Toast" \n   - Font: A more understated, friendly font, possibly italicized.\n   - Position: Placed at the bottom or along the side, ensuring it doesn’t cover critical visual elements.\n\n**Overall Composition:**\n- Utilize the rule of thirds; place the character slightly off-center to draw the viewer’s eye naturally towards both them and the toast.\n- Ensure there’s enough space in the thumbnail for the text overlay while keeping the elements balanced and engaging.\n- The blend of inviting colors and cheerful expressions will evoke curiosity, enticing viewers to click and engage with the video\'s content about intimate morning routines and self-reflection.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Figure:** A cheerful, relatable person (can be male or female) in a cozy kitchen setting. They should be mid-action, spreading butter on a piece of warm toast, with a warm smile on their face to convey a sense of joy.\n2. **Toast Focus:** The toast should be prominently displayed, with glistening butter melting on its surface, inviting viewers to feel the warmth and taste the freshness.\n3. **Background Details:** A soft-focus kitchen scene in the background, featuring elements like a vintage toaster, a sunny window with soft light pouring through, and a coffee cup steaming nearby. This sets an inviting and homely atmosphere.\n4. **Speech Bubble:** Include a playful speech bubble above the individual, capturing a snippet of their self-conversation (e.g., "Another delicious day begins!").\n\n**Color Scheme:**\n- **Warm Tones:** Use a palette of warm yellows, soft browns, and creamy whites to evoke feelings of comfort and warmth. \n- **Accent Colors:** Incorporate hints of pastel colors (light blue or soft green) for kitchen elements to add balance without overwhelming the main focus.\n- **Contrast:** Ensure the toast and butter have a slightly brighter hue against the background to draw attention immediately.\n\n**Text Overlay Suggestions:**\n- **Main Title Text:** "Morning Bliss!" in bold, playful fonts at the top of the thumbnail. Use white or light yellow with a subtle shadow for better visibility.\n- **Subtext:** A smaller line below the main title saying "Join the Breakfast Chat!" in a contrasting font style, perhaps in a light pastel color, to make it eye-catching but not overpowering.\n\n**Overall Composition:**\n- The individual should be positioned slightly off-center (rule of thirds), with the toast angled towards the viewer to create depth.\n- The text overlay should be placed at the upper and lower parts of the thumbnail to keep the central focus on the toast and the person, avoiding clutter.\n- A subtle drop shadow behind the main title text can help it stand out against the background for enhanced readability.\n\nBy combining a joyful scene with warm colors and engaging text, this thumbnail will evoke curiosity and draw viewers in, enticing them to click and explore the daily ritual depicted in the video.'],
#  'thumbnail_sketches': ['thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg'],
#  'final_summary': 'The video transcription portrays a surprising morning scene where an individual engages in a self-conversation while preparing breakfast. The focus is on the person spreading butter on a piece of warm, freshly toasted bread, which adds a tactile and sensory element to the moment, emphasizing both the mundane and intimate aspects of the daily routine.',
#  'user_feedback': 'Make sure the fella is smiling, remove any mention of audible, or any logo, and give it a photo realistic, 3d style.',
#  'chosen_prompt': "**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Character:** A mid-30s individual with an expressive face, looking thoughtfully at a slice of toast. They should be depicted in a cozy kitchen setting, with soft morning light streaming in through the window.\n2. **Toast and Butter:** A close-up of the individual's hand spreading creamy butter on a golden-brown slice of toast, capturing the luscious texture of the butter melting slightly.\n3. **Background Details:** A small kitchen table with an array of colorful ingredients (like jam in a jar, fresh fruit, a coffee cup) to create a welcoming atmosphere. A few kitchen appliances could be visible, like a kettle or toaster, subtly blurred to maintain focus on the main character.\n4. **Emotion:** The character’s expression should convey a sense of wonder or contemplation, hinting at the theme of self-conversation and introspection.\n\n**Color Scheme:**\n- **Warm and Inviting Tones:** Use soft yellows and warm beige inspired by morning light, contrasted with pops of green (from the fresh ingredients) and a hint of deep brown (for the toast).\n- **Soft Focus on Background:** Slightly blurred greens and browns for the kitchen background to create depth.\n\n**Text Overlay Suggestions:**\n- **Main Title:** “Morning Conversations” in a bold, playful font. \n- **Subtitle:** “A Simple Breakfast Ritual” in a smaller, elegant font below it. \n- **Color and Style:** Use white or light yellow for the text, ensuring it pops against the background but retains readability. Consider adding a subtle drop shadow to enhance visibility.\n\n**Overall Composition:**\n- Center the character slightly off to the left, with the toast and butter in sharp focus on the right side of the thumbnail. \n- Ensure the text is positioned in the upper part of the thumbnail, leaving enough space around it for a clean look.\n- Use a soft vignette effect around the edges to draw the viewer’s eye towards the center, creating a cozy and inviting feel that invites viewers to click on the video.\n\nThis prompt is designed to create an engaging thumbnail that reflects both the intimate nature of the video while also hinting at the simplicity and depth found in everyday moments."}
